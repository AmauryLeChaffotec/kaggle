# %% [markdown]
# ### Winning solutions of kaggle competitions: ###
#
# Generally at the end of every Kaggle competition, winners and other toppers used to share their solutions in the discussion forums. But it is a tedious task to search for the competitions and then for the solutions of these competitions when we need them. I always wanted to get the links to the solutions of all past Kaggle competitions at one place. I thought it would be a very good reference point many a times. Thanks to Kaggle team for the Meta Kaggle dataset, now I am able to get them in one single place through this notebook .
#
# Thanks a lot to [@sban](https://www.kaggle.com/shivamb) for this [wonderful kernel](https://www.kaggle.com/shivamb/data-science-glossary-on-kaggle/notebook) without which I wouldn't have got this notebook.
#
# I have inlcuded only "Featured" & "Research" competitions and the competitions are ordered based on recency. The solutions are ordered based on the number of upvotes received.
#
# Have fun and Happy Kaggling.!
#
# P.S : There are few outlier discussions (which are not actually solutions) too ;)
#
# In case if you find any of the solutions missing, please post them on the comments section with links. I will add them here.
#
# Thanks to notebook scheduler functionality by Kaggle, the script will automatically run once every month and update the results.

# %%
import numpy as np
import pandas as pd
from IPython.core.display import HTML

import warnings
warnings.filterwarnings("ignore")

data_path = "../input/"

competitions_df = pd.read_csv(data_path + "Competitions.csv")
comps_to_use = ["Featured", "Research", "Recruitment"]
competitions_df = competitions_df[competitions_df["HostSegmentTitle"].isin(comps_to_use)]
competitions_df["EnabledDate"] = pd.to_datetime(competitions_df["EnabledDate"], format="%m/%d/%Y %H:%M:%S")
competitions_df = competitions_df.sort_values(by="EnabledDate", ascending=False).reset_index(drop=True)
competitions_df.head()

forum_topics_df = pd.read_csv(data_path + "ForumTopics.csv")

comp_tags_df = pd.read_csv(data_path + "CompetitionTags.csv")
tags_df = pd.read_csv(data_path + "Tags.csv", usecols=["Id", "Name"])

def get_comp_tags(comp_id):
    temp_df = comp_tags_df[comp_tags_df["CompetitionId"]==comp_id]
    temp_df = pd.merge(temp_df, tags_df, left_on="TagId", right_on="Id")
    tags_str = "Tags : "
    for ind, row in temp_df.iterrows():
        tags_str += row["Name"] + ", "
    return tags_str.strip(", ")

def check_solution(topic):
    is_solution = False
    to_exclude = ["?", "submit", "why", "what", "resolution", "benchmark"]
    if "solution" in topic.lower():
        is_solution = True
        for exc in to_exclude:
            if exc in topic.lower():
                is_solution = False
    to_include = ["2nd place code", '"dance with ensemble" sharing']
    for inc in to_include:
        if inc in topic.lower():
            is_solution = True
    return is_solution

def get_discussion_results(forum_id, n):
    results_df = forum_topics_df[forum_topics_df["ForumId"]==forum_id]
    results_df["is_solution"] = results_df["Title"].apply(lambda x: check_solution(str(x)))
    results_df = results_df[results_df["is_solution"] == 1]
    results_df = results_df.sort_values(by=["Score","TotalMessages"], ascending=False).head(n).reset_index(drop=True)
    return results_df[["Title", "Id", "Score", "TotalMessages", "TotalReplies"]]

def render_html_for_comp(forum_id, comp_id, comp_name, comp_slug, comp_subtitle, n):
    results_df = get_discussion_results(forum_id, n)
    
    if len(results_df) < 1:
        return
    
    comp_tags = get_comp_tags(comp_id)
    
    comp_url = "https://www.kaggle.com/c/"+str(comp_slug)
    hs = """<style>
                .rendered_html tr {font-size: 12px; text-align: left;}
                th {
                text-align: left;
                }
            </style>
            <h3><font color="#1768ea"><a href="""+comp_url+""">"""+comp_name+"""</font></h3>
            <p>"""+comp_subtitle+"""</p>
            """
    
    if comp_tags != "Tags :":
        hs +=   """
            <p>"""+comp_tags+"""</p>
            """
    
    hs +=   """
            <table>
            <tr>
                <th><b>S.No</b></th>
                <th><b>Discussion Title</b></th>
                <th><b>Number of upvotes</b></th>
                <th><b>Total Replies</b></th>
            </tr>"""
    
    for i, row in results_df.iterrows():
        url = "https://www.kaggle.com/c/"+str(comp_slug)+"/discussion/"+str(row["Id"])
        hs += """<tr>
                    <td>"""+str(i+1)+"""</td>
                    <td><a href="""+url+""" target="_blank"><b>"""  +str(row['Title']) + """</b></a></td>
                    <td>"""+str(row['Score'])+"""</td>
                    <td>"""+str(row['TotalReplies'])+"""</td>
                    </tr>"""
    hs += "</table>"
    display(HTML(hs))

for ind, comp_row in competitions_df.iterrows():
    render_html_for_comp(comp_row["ForumId"], comp_row["Id"], comp_row["Title"], comp_row["Slug"], comp_row["Subtitle"], 12)
# Out:
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/santa-2025>Santa 2025 - Christmas Tree Packing Challenge</font></h3>
#             <p>How many Christmas trees can fit in a box? Help solve a classic optimization problem with a festive twist.</p>
#
#             <p>Tags : optimization, holidays and cultural events</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/671058 target="_blank"><b>1st place solution preview</b></a></td>
#                     <td>84</td>
#                     <td>25</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/629896 target="_blank"><b>Visualization of my 10 trees solution. This year's santa is going to be a hard competition.</b></a></td>
#                     <td>65</td>
#                     <td>42</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/671181 target="_blank"><b>Third place solution: a customized sparrow algorithm</b></a></td>
#                     <td>61</td>
#                     <td>9</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/664824 target="_blank"><b>Symmetric solutions that are apparently optimal</b></a></td>
#                     <td>46</td>
#                     <td>32</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/670298 target="_blank"><b>Please stop sharing public solutions</b></a></td>
#                     <td>36</td>
#                     <td>25</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/637458 target="_blank"><b>About Sharing Solutions</b></a></td>
#                     <td>29</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/672466 target="_blank"><b>Santa 2025 5th-place solution</b></a></td>
#                     <td>24</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/666583 target="_blank"><b>A simple web application for editing solutions</b></a></td>
#                     <td>23</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/637382 target="_blank"><b>Chaos verus orderd solution</b></a></td>
#                     <td>18</td>
#                     <td>24</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/637061 target="_blank"><b>Open Forum to Showcase your 100 Trees Solution</b></a></td>
#                     <td>17</td>
#                     <td>30</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/671134 target="_blank"><b>11th Place Solution</b></a></td>
#                     <td>15</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/santa-2025/discussion/671151 target="_blank"><b>19th place solution: Loosen up, add a tree, and let the sparrows explore</b></a></td>
#                     <td>10</td>
#                     <td>3</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/csiro-biomass>CSIRO - Image2Biomass Prediction</font></h3>
#             <p>Predict biomass using the provided pasture images</p>
#
#             <p>Tags : biology, agriculture</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/670735 target="_blank"><b>1st Place Solution</b></a></td>
#                     <td>127</td>
#                     <td>28</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/670668 target="_blank"><b>Rank 5th Solution</b></a></td>
#                     <td>79</td>
#                     <td>14</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/670677 target="_blank"><b>4th Place Solution: ViT-Huge DINOv3 & Multi-Modal Feature Fusion with AUX predic</b></a></td>
#                     <td>46</td>
#                     <td>14</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/670654 target="_blank"><b>7th Place Solution - single/dual+TTT</b></a></td>
#                     <td>41</td>
#                     <td>17</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/670672 target="_blank"><b>🏅 37st Place Solution: Self Prompt Tuning with DINOv3</b></a></td>
#                     <td>36</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/670901 target="_blank"><b>3rd Place Solution</b></a></td>
#                     <td>28</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/670986 target="_blank"><b>33rd Place Silver Medal Solution</b></a></td>
#                     <td>25</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/671211 target="_blank"><b>5th place solution</b></a></td>
#                     <td>20</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/670759 target="_blank"><b>123rd (public 6th) Solution - Tile-based ViT with 2D Pos-Emb & MIL pooling</b></a></td>
#                     <td>15</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/671053 target="_blank"><b>10th Place Solution</b></a></td>
#                     <td>13</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/670653 target="_blank"><b>Rank 28 Solution</b></a></td>
#                     <td>12</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/csiro-biomass/discussion/671026 target="_blank"><b>9th Place Solution</b></a></td>
#                     <td>12</td>
#                     <td>1</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization>PhysioNet - Digitization of ECG Images</font></h3>
#             <p>Extract the ECG time-series data from scans and photographs of paper printouts of the ECGs.</p>
#
#             <p>Tags : health, medicine, time series analysis</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/669584 target="_blank"><b>1st place solution</b></a></td>
#                     <td>69</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/669548 target="_blank"><b>7th place solution</b></a></td>
#                     <td>47</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/613540 target="_blank"><b>[placeholder] Let's design winning solution step by step</b></a></td>
#                     <td>40</td>
#                     <td>40</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/669871 target="_blank"><b>2nd place solution</b></a></td>
#                     <td>32</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/669668 target="_blank"><b>3rd place solution</b></a></td>
#                     <td>30</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/669562 target="_blank"><b>6th place solution</b></a></td>
#                     <td>28</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/669546 target="_blank"><b>13th Place Solution</b></a></td>
#                     <td>27</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/669897 target="_blank"><b>4th Place Solution</b></a></td>
#                     <td>25</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/670227 target="_blank"><b>5th place solution: Multi-stages Heatmap-based Modeling</b></a></td>
#                     <td>24</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/613391 target="_blank"><b>reference solution: High Precision ECG Digitization Using Artificial Intelligence - medRxiv, 2024-sep</b></a></td>
#                     <td>23</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/669558 target="_blank"><b>14th Place Solution</b></a></td>
#                     <td>21</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/physionet-ecg-image-digitization/discussion/669645 target="_blank"><b>21st Place Solution</b></a></td>
#                     <td>20</td>
#                     <td>8</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction>NFL Big Data Bowl 2026 - Prediction</font></h3>
#             <p>Predict player movement while the ball is in the air</p>
#
#             <p>Tags : football, sports</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction/discussion/651604 target="_blank"><b>1st Place Solution</b></a></td>
#                     <td>137</td>
#                     <td>34</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction/discussion/651814 target="_blank"><b>Private 4th / Public 5th Place Solution</b></a></td>
#                     <td>43</td>
#                     <td>9</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction/discussion/668048 target="_blank"><b>3rd Place Solution</b></a></td>
#                     <td>40</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction/discussion/651530 target="_blank"><b>[33rd solution] Transformer+Augmentation Tricks</b></a></td>
#                     <td>31</td>
#                     <td>15</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction/discussion/651520 target="_blank"><b>19th Place Solution</b></a></td>
#                     <td>20</td>
#                     <td>8</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction/discussion/666799 target="_blank"><b>5th Place Solution</b></a></td>
#                     <td>20</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction/discussion/651651 target="_blank"><b>Private 24th | Public 23rd solution - Data augmentation</b></a></td>
#                     <td>17</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction/discussion/668572 target="_blank"><b>2nd place solution</b></a></td>
#                     <td>15</td>
#                     <td>16</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction/discussion/651652 target="_blank"><b>GRU Solution</b></a></td>
#                     <td>12</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction/discussion/651730 target="_blank"><b>Public LB 0.504 Solution</b></a></td>
#                     <td>4</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/nfl-big-data-bowl-2026-prediction/discussion/673957 target="_blank"><b>86th Place Solution for the NFL Big Data Bowl 2026 - Prediction Competition</b></a></td>
#                     <td>0</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection>MABe Challenge - Social Action Recognition in Mice</font></h3>
#             <p>Detect unique behaviors from pose estimates of mice.</p>
#
#             <p>Tags : biology, time series analysis, classification, deep learning, transfer learning</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/663026 target="_blank"><b>3rd place solution</b></a></td>
#                     <td>52</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/663083 target="_blank"><b>2nd place solution</b></a></td>
#                     <td>45</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/609063 target="_blank"><b>place holder: 1d object detection solution</b></a></td>
#                     <td>42</td>
#                     <td>14</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/663181 target="_blank"><b>4th Place Solution - XGB + NN Ensemble</b></a></td>
#                     <td>26</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/663108 target="_blank"><b>13th Public/12th Private Solution</b></a></td>
#                     <td>25</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/663063 target="_blank"><b>10th Place Solution (ST-GCN + Transformer)</b></a></td>
#                     <td>25</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/663028 target="_blank"><b>6th Place Solution (yu4u's Part)</b></a></td>
#                     <td>23</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/663032 target="_blank"><b>6th Place Solution (monnu's Part)</b></a></td>
#                     <td>22</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/663073 target="_blank"><b>15th place solution</b></a></td>
#                     <td>18</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/663049 target="_blank"><b>27th place solution</b></a></td>
#                     <td>18</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/663274 target="_blank"><b>52th Place Solution: Feature Engineering & Post-Processing Improvements</b></a></td>
#                     <td>14</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/MABe-mouse-behavior-detection/discussion/663082 target="_blank"><b>26th place solution</b></a></td>
#                     <td>7</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/openai-gpt-oss-20b-red-teaming>Red‑Teaming Challenge - OpenAI gpt-oss-20b</font></h3>
#             <p>Find any flaws and vulnerabilities in gpt-oss-20b that have not been previously discovered or reported.</p>
#
#             <p>Tags : nlp, adversarial learning</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/openai-gpt-oss-20b-red-teaming/discussion/598491 target="_blank"><b>gpt oss is heavy need solution</b></a></td>
#                     <td>0</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/google-code-golf-2025>NeurIPS 2025 - Google Code Golf Championship</font></h3>
#             <p>Implement a variety of programs using the fewest number of characters!</p>
#
#             <p>Tags : optimization</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/613968 target="_blank"><b>Link to solutions</b></a></td>
#                     <td>40</td>
#                     <td>19</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/618673 target="_blank"><b>2nd place solution</b></a></td>
#                     <td>24</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/608190 target="_blank"><b>🎯 ARC Starter Solutions - All 400 Tasks</b></a></td>
#                     <td>20</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/614729 target="_blank"><b>19th Place Yuchen20 part of write up (a LLM agentic solution)</b></a></td>
#                     <td>17</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/596328 target="_blank"><b>Solution time limit</b></a></td>
#                     <td>13</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/613437 target="_blank"><b>Our worst 20 solutions lol</b></a></td>
#                     <td>12</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/614199 target="_blank"><b>Memorable solutions</b></a></td>
#                     <td>11</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/614727 target="_blank"><b>15th Place Solution</b></a></td>
#                     <td>11</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/594035 target="_blank"><b>Golf Tasks 2 AGI ARC 1 Ids ( We can copy old solutions )</b></a></td>
#                     <td>10</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/615145 target="_blank"><b>6th Place Solution for Google Code Golf Championship</b></a></td>
#                     <td>9</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/608989 target="_blank"><b>Using sh In Solutions</b></a></td>
#                     <td>7</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/google-code-golf-2025/discussion/596469 target="_blank"><b>Strict type requirements in solutions</b></a></td>
#                     <td>7</td>
#                     <td>1</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection>RSNA Intracranial Aneurysm Detection</font></h3>
#             <p>Detect the presence and location of intracranial aneurysms in multimodal imaging data</p>
#
#             <p>Tags : medicine, multilabel classification, image classification</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/611846 target="_blank"><b>1st Place Solution</b></a></td>
#                     <td>148</td>
#                     <td>36</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/611849 target="_blank"><b>5th place solution with code</b></a></td>
#                     <td>52</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/611908 target="_blank"><b>9th place solution</b></a></td>
#                     <td>47</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/611856 target="_blank"><b>3rd place solution</b></a></td>
#                     <td>46</td>
#                     <td>12</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/611893 target="_blank"><b>4th Place Solution</b></a></td>
#                     <td>44</td>
#                     <td>20</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/611867 target="_blank"><b>2nd Place Solution</b></a></td>
#                     <td>39</td>
#                     <td>8</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/611925 target="_blank"><b>6th Place Solution</b></a></td>
#                     <td>38</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/612039 target="_blank"><b>7th place solution - 3D nnU-Net + blob regression (again)</b></a></td>
#                     <td>24</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/612186 target="_blank"><b>11th Place Solution</b></a></td>
#                     <td>23</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/611858 target="_blank"><b>55st Place Solution</b></a></td>
#                     <td>14</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/611907 target="_blank"><b>38th Place Solution</b></a></td>
#                     <td>14</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/rsna-intracranial-aneurysm-detection/discussion/612006 target="_blank"><b>18th Place Solution</b></a></td>
#                     <td>12</td>
#                     <td>6</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/mitsui-commodity-prediction-challenge>MITSUI&CO. Commodity Prediction Challenge</font></h3>
#             <p>Develop a robust model for accurate and stable prediction of commodity prices</p>
#
#             <p>Tags : finance, investing</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/mitsui-commodity-prediction-challenge/discussion/668769 target="_blank"><b>3 rd place solution - Directional Trends Over Volatile Noise</b></a></td>
#                     <td>31</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/mitsui-commodity-prediction-challenge/discussion/668589 target="_blank"><b>Regularized-naive #10 solution</b></a></td>
#                     <td>17</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/mitsui-commodity-prediction-challenge/discussion/668673 target="_blank"><b>MITSUI&CO. Commodity Prediction Challenge - 15th Place Solution Writeup</b></a></td>
#                     <td>15</td>
#                     <td>5</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/mitsui-commodity-prediction-challenge/discussion/668781 target="_blank"><b>89th Place Solution</b></a></td>
#                     <td>5</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/mitsui-commodity-prediction-challenge/discussion/670526 target="_blank"><b>ZLF's Solution in the MITSUI&CO. Commodity Prediction Challenge</b></a></td>
#                     <td>5</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/mitsui-commodity-prediction-challenge/discussion/669234 target="_blank"><b>26th Place Solution – MITSUI&CO. Commodity Prediction Challenge Writeup</b></a></td>
#                     <td>4</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/mitsui-commodity-prediction-challenge/discussion/668698 target="_blank"><b>97th Place Solution</b></a></td>
#                     <td>4</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/mitsui-commodity-prediction-challenge/discussion/668669 target="_blank"><b>37th Place Solution for the MITSUI&CO. Commodity Prediction Challenge</b></a></td>
#                     <td>3</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/mitsui-commodity-prediction-challenge/discussion/670493 target="_blank"><b>Transformer Based Solution</b></a></td>
#                     <td>1</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules>Jigsaw - Agile Community Rules Classification</font></h3>
#             <p>Using AI models to help moderators uphold community-specific norms.</p>
#
#             <p>Tags : classification, text, social networks, text classification, english</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/613305 target="_blank"><b>1st place solution</b></a></td>
#                     <td>116</td>
#                     <td>33</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/613150 target="_blank"><b>6th Place Solution: Online Distillation via Deep Mutual Learning</b></a></td>
#                     <td>107</td>
#                     <td>53</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/613071 target="_blank"><b>18th Solution(public 11th)</b></a></td>
#                     <td>62</td>
#                     <td>15</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/613215 target="_blank"><b>7th place solution</b></a></td>
#                     <td>40</td>
#                     <td>8</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/613096 target="_blank"><b>12th place solution</b></a></td>
#                     <td>39</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/613324 target="_blank"><b>3rd Place Solution</b></a></td>
#                     <td>35</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/613185 target="_blank"><b>9th Place Solution: Bringing It All Together</b></a></td>
#                     <td>33</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/613421 target="_blank"><b>5th Place solution - Diverse Ensemble</b></a></td>
#                     <td>23</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/591187 target="_blank"><b>Some references to top solutions from previous text and nlp comps</b></a></td>
#                     <td>18</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/613265 target="_blank"><b>13th Place Solution: Using Positive Examples from Other Rules as Negative Exampl</b></a></td>
#                     <td>15</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/613611 target="_blank"><b>15th Place Solution</b></a></td>
#                     <td>12</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/jigsaw-agile-community-rules/discussion/613131 target="_blank"><b>Solution Writeup: Jigsaw - Agile Community Rules Classification</b></a></td>
#                     <td>11</td>
#                     <td>1</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings>MAP - Charting Student Math Misunderstandings</font></h3>
#             <p>Predict the affinity between misconceptions and student open-ended responses</p>
#
#             <p>Tags : education, nlp, primary and secondary schools</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612268 target="_blank"><b>1st Place Solution</b></a></td>
#                     <td>185</td>
#                     <td>29</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612059 target="_blank"><b>3rd place (Public 1st) solution : monsaraida & Masaya</b></a></td>
#                     <td>77</td>
#                     <td>9</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612038 target="_blank"><b>10th Place Solution</b></a></td>
#                     <td>64</td>
#                     <td>23</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612099 target="_blank"><b>✨ MAP 6th Place Solution - Qwen-semble FTW! 🚀</b></a></td>
#                     <td>44</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612101 target="_blank"><b>8th Place Solution</b></a></td>
#                     <td>37</td>
#                     <td>10</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612124 target="_blank"><b>5th place solution</b></a></td>
#                     <td>31</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612178 target="_blank"><b>4th Place Solution (single model pb 0.948 lb 0.951)</b></a></td>
#                     <td>28</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612134 target="_blank"><b>Private 7th (Public 10th) Place Solution</b></a></td>
#                     <td>27</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612003 target="_blank"><b>Public 8th / Private 24th Solution (Miss a gold solution)</b></a></td>
#                     <td>26</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612062 target="_blank"><b>15th Place Solution Writeup</b></a></td>
#                     <td>26</td>
#                     <td>3</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612069 target="_blank"><b>MAP Competition 13th Place Gold Medal Solution</b></a></td>
#                     <td>24</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/map-charting-student-math-misunderstandings/discussion/612105 target="_blank"><b>9th Place Solution</b></a></td>
#                     <td>22</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/ariel-data-challenge-2025>NeurIPS - Ariel Data Challenge 2025</font></h3>
#             <p>Derive exoplanet signals from Ariel's optical instruments</p>
#
#             <p>Tags : astronomy, intermediate, regression, multimodal</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/609888 target="_blank"><b>1st place solution: Bayesian Inference, of course</b></a></td>
#                     <td>47</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/609252 target="_blank"><b>3rd Place Solution</b></a></td>
#                     <td>32</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/609276 target="_blank"><b>6th Place Solution Batman-Minuit</b></a></td>
#                     <td>28</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>4</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/609210 target="_blank"><b>7th Place Solution</b></a></td>
#                     <td>28</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>5</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/609443 target="_blank"><b>9th Solution</b></a></td>
#                     <td>23</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>6</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/586581 target="_blank"><b>Top 3 Solutions from 2024 NeurIPS Ariel Data Challenge summarized (in tabular format)</b></a></td>
#                     <td>19</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>7</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/610252 target="_blank"><b>2nd Place Solution</b></a></td>
#                     <td>18</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>8</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/609629 target="_blank"><b>5th place solution</b></a></td>
#                     <td>18</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>9</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/609510 target="_blank"><b>8th place solution</b></a></td>
#                     <td>14</td>
#                     <td>0</td>
#                     </tr><tr>
#                     <td>10</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/586519 target="_blank"><b>Winning Solutions - NeurIPS - Ariel Data Challenge 2024</b></a></td>
#                     <td>10</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>11</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/609375 target="_blank"><b>12th Place Solution: E2E NN</b></a></td>
#                     <td>8</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>12</td>
#                     <td><a href=https://www.kaggle.com/c/ariel-data-challenge-2025/discussion/609445 target="_blank"><b>10th Place Solution – Solverworld part</b></a></td>
#                     <td>8</td>
#                     <td>1</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/google-gemma-3n-hackathon>Google - The Gemma 3n Impact Challenge</font></h3>
#             <p>Explore the newest Gemma model and build your best products for a better world</p>
#
#             <p>Tags : tabular, text</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
# ...
#                     <td>1</td>
#                     <td>2</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/kddcup2012-track1>KDD Cup 2012, Track 1</font></h3>
#             <p>Predict which users (or information sources) one user might follow in Tencent Weibo.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/kddcup2012-track1/discussion/2335 target="_blank"><b>Solution Posted</b></a></td>
#                     <td>0</td>
#                     <td>2</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/asap-aes>The Hewlett Foundation: Automated Essay Scoring</font></h3>
#             <p>Develop an automated scoring algorithm for student-written essays.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/asap-aes/discussion/229208 target="_blank"><b>optimal solution</b></a></td>
#                     <td>1</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/DontGetKicked>Don't Get Kicked!</font></h3>
#             <p>Predict if a car purchased at auction is a lemon</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/DontGetKicked/discussion/7524 target="_blank"><b>Solution</b></a></td>
#                     <td>1</td>
#                     <td>58</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/GiveMeSomeCredit>Give Me Some Credit</font></h3>
#             <p>Improve on the state of the art in credit scoring by predicting the probability that somebody will experience financial distress in the next two years.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/GiveMeSomeCredit/discussion/300684 target="_blank"><b>How i get the  Top 5 solution  :Give me Some Credit !!</b></a></td>
#                     <td>5</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/GiveMeSomeCredit/discussion/2788 target="_blank"><b>Winning solution(s)</b></a></td>
#                     <td>2</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/GiveMeSomeCredit/discussion/26536 target="_blank"><b>Automatic ML solution (6th place)</b></a></td>
#                     <td>1</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/dunnhumbychallenge>dunnhumby's Shopper Challenge</font></h3>
#             <p>Going grocery shopping, we all have to do it, some even enjoy it, but can you predict it? dunnhumby is looking to build a model to better predict when supermarket shoppers will next visit the store and how much they will spend.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/dunnhumbychallenge/discussion/749 target="_blank"><b>naive solution</b></a></td>
#                     <td>0</td>
#                     <td>6</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/dunnhumbychallenge/discussion/762 target="_blank"><b>an example simple solution</b></a></td>
#                     <td>0</td>
#                     <td>4</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/mdm>Mapping Dark Matter</font></h3>
#             <p>Measure the small distortion in galaxy images caused by dark matter</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/mdm/discussion/605 target="_blank"><b>mdm_training_solution.csv file</b></a></td>
#                     <td>0</td>
#                     <td>27</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/mdm/discussion/796 target="_blank"><b>Solution</b></a></td>
#                     <td>0</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/mdm/discussion/614 target="_blank"><b>Updated training solution and rescore</b></a></td>
#                     <td>0</td>
#                     <td>4</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/hhp>Heritage Health Prize</font></h3>
#             <p>Identify patients who will be admitted to a hospital within the next year using historical claims data. (Enter by 06:59:59 UTC Oct 4 2012)</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/hhp/discussion/409 target="_blank"><b>Evaluation Metric Issues: Solutions where 100% of patients went to hospital could have higher score!</b></a></td>
#                     <td>0</td>
#                     <td>36</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/hhp/discussion/390 target="_blank"><b>Solution idea for limited data problems, reidentification attacks</b></a></td>
#                     <td>0</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/hhp/discussion/1272 target="_blank"><b>First Milestone Solution</b></a></td>
#                     <td>0</td>
#                     <td>1</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/ChessRatings2>Deloitte/FIDE Chess Rating Challenge</font></h3>
#             <p>This contest, sponsored by professional services firm Deloitte, will find the most accurate system to predict chess outcomes, and FIDE will also bring a top finisher to Athens to present their system</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/ChessRatings2/discussion/575 target="_blank"><b>Follow-up Solution Set</b></a></td>
#                     <td>0</td>
#                     <td>1</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/ChessRatings2/discussion/505 target="_blank"><b>Test Solution File</b></a></td>
#                     <td>0</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/stayalert>Stay Alert! The Ford Challenge</font></h3>
#             <p>Driving while not alert can be deadly. The objective is to design a classifier that will detect whether the driver is alert or not alert, employing data that are acquired while driving.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/stayalert/discussion/279 target="_blank"><b>Solutions</b></a></td>
#                     <td>0</td>
#                     <td>2</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/stayalert/discussion/280 target="_blank"><b>Solutions</b></a></td>
#                     <td>0</td>
#                     <td>0</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/unimelb>Predict Grant Applications</font></h3>
#             <p>This task requires participants to predict the outcome of grant applications for the University of Melbourne.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/unimelb/discussion/302 target="_blank"><b>Solution</b></a></td>
#                     <td>11</td>
#                     <td>11</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/unimelb/discussion/21894 target="_blank"><b>Trying to check a submission: "This competition does not have a solution to test a submission against"</b></a></td>
#                     <td>3</td>
#                     <td>1</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/RTA>RTA Freeway Travel Time Prediction</font></h3>
#             <p>This competition requires participants to predict travel time on Sydney's M4 freeway from past travel time observations.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/RTA/discussion/294 target="_blank"><b>Solution</b></a></td>
#                     <td>1</td>
#                     <td>10</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/worldcupconf>World Cup 2010 - Confidence Challenge</font></h3>
#             <p>The Confidence Challenge requires competitors to assign a level of confidence to their World Cup predictions.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/worldcupconf/discussion/73 target="_blank"><b>Solution file</b></a></td>
#                     <td>1</td>
#                     <td>5</td>
#                     </tr></table>
# <style>
#                 .rendered_html tr {font-size: 12px; text-align: left;}
#                 th {
#                 text-align: left;
#                 }
#             </style>
#             <h3><font color="#1768ea"><a href=https://www.kaggle.com/c/hivprogression>Predict HIV Progression</font></h3>
#             <p>This contest requires competitors to predict the likelihood that an HIV patient's infection will become less severe, given a small dataset and limited clinical information.</p>
#
#             <table>
#             <tr>
#                 <th><b>S.No</b></th>
#                 <th><b>Discussion Title</b></th>
#                 <th><b>Number of upvotes</b></th>
#                 <th><b>Total Replies</b></th>
#             </tr><tr>
#                     <td>1</td>
#                     <td><a href=https://www.kaggle.com/c/hivprogression/discussion/46 target="_blank"><b>The solution</b></a></td>
#                     <td>0</td>
#                     <td>7</td>
#                     </tr><tr>
#                     <td>2</td>
#                     <td><a href=https://www.kaggle.com/c/hivprogression/discussion/119608 target="_blank"><b>Submissions Closed/Solution Data Unavailable</b></a></td>
#                     <td>0</td>
#                     <td>4</td>
#                     </tr><tr>
#                     <td>3</td>
#                     <td><a href=https://www.kaggle.com/c/hivprogression/discussion/514083 target="_blank"><b>Solution notebook</b></a></td>
#                     <td>0</td>
#                     <td>0</td>
#                     </tr></table>
